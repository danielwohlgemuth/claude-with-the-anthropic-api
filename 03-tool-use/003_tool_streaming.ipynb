# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic


load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions


def add_user_message(messages, message):
    if isinstance(message, list):
        user_message = {
            "role": "user",
            "content": message,
        }
    else:
        user_message = {
            "role": "user",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(user_message)


def add_assistant_message(messages, message):
    if isinstance(message, list):
        assistant_message = {
            "role": "assistant",
            "content": message,
        }
    elif hasattr(message, "content"):
        content_list = []
        for block in message.content:
            if block.type == "text":
                content_list.append({"type": "text", "text": block.text})
            elif block.type == "tool_use":
                content_list.append(
                    {
                        "type": "tool_use",
                        "id": block.id,
                        "name": block.name,
                        "input": block.input,
                    }
                )
        assistant_message = {
            "role": "assistant",
            "content": content_list,
        }
    else:
        # String messages need to be wrapped in a list with text block
        assistant_message = {
            "role": "assistant",
            "content": [{"type": "text", "text": message}],
        }
    messages.append(assistant_message)


def chat_stream(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    tool_choice=None,
    betas=[],
):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if tool_choice:
        params["tool_choice"] = tool_choice

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    if betas:
        params["betas"] = betas

    return client.beta.messages.stream(**params)


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
# Tool definition
from anthropic.types import ToolParam

save_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Eight sentence review of the paper",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)
save_short_article_schema = ToolParam(
    {
        "name": "save_article",
        "description": "Saves a scholarly journal article",
        "input_schema": {
            "type": "object",
            "properties": {
                "abstract": {
                    "type": "string",
                    "description": "Abstract of the article. One short sentence max",
                },
                "meta": {
                    "type": "object",
                    "properties": {
                        "word_count": {
                            "type": "integer",
                            "description": "Word count",
                        },
                        "review": {
                            "type": "string",
                            "description": "Review of paper. One short sentence max",
                        },
                    },
                    "required": ["word_count", "review"],
                },
            },
            "required": ["abstract", "meta"],
        },
    }
)


def save_article(**kwargs):
    return "Article saved!"

# %%
# Tool Running
import json


def run_tool(tool_name, tool_input):
    if tool_name == "save_article":
        return save_article(**tool_input)


def run_tools(message):
    tool_requests = [block for block in message.content if block.type == "tool_use"]
    tool_result_blocks = []

    for tool_request in tool_requests:
        try:
            tool_output = run_tool(tool_request.name, tool_request.input)
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": json.dumps(tool_output),
                "is_error": False,
            }
        except Exception as e:
            tool_result_block = {
                "type": "tool_result",
                "tool_use_id": tool_request.id,
                "content": f"Error: {e}",
                "is_error": True,
            }

        tool_result_blocks.append(tool_result_block)

    return tool_result_blocks

# %%
# Run conversation
def run_conversation(messages, tools=[], tool_choice=None, fine_grained=False):
    while True:
        with chat_stream(
            messages,
            tools=tools,
            betas=["fine-grained-tool-streaming-2025-05-14"] if fine_grained else [],
            tool_choice=tool_choice,
        ) as stream:
            for chunk in stream:
                if chunk.type == "text":
                    print(chunk.text, end="")

                if chunk.type == "content_block_start":
                    if chunk.content_block.type == "tool_use":
                        print(f'\n>>> Tool Call: "{chunk.content_block.name}"')

                if chunk.type == "input_json" and chunk.partial_json:
                    print(chunk.partial_json, end="")

                if chunk.type == "content_block_stop":
                    print("\n")

            response = stream.get_final_message()

        add_assistant_message(messages, response)

        if response.stop_reason != "tool_use":
            break

        tool_results = run_tools(response)
        add_user_message(messages, tool_results)

        if tool_choice:
            break

    return messages

# %%
messages = []

add_user_message(
    messages,
    "Create and save a fake computer science article",
)

run_conversation(
    messages,
    tools=[save_article_schema],
)
# Out:
# >>> Tool Call: "save_article"
# {"abstract": "A novel quantum-inspired algorithm for optimizing neural network architectures through biomimetic swarm intelligence.", "meta": {"word_count":8750,"review":"This paper presents an innovative approach to neural network optimization that draws inspiration from quantum computing principles and swarm behavior observed in nature. The authors propose a hybrid algorithm that combines elements of quantum mechanics with ant colony optimization to improve hyperparameter tuning in deep learning models. The experimental results on benchmark datasets show promising improvements over traditional gradient descent methods, with a 23% reduction in training time on average. The theoretical foundations are well-grounded in established literature, though the mathematical proofs could benefit from more rigorous exposition in places. The practical applicability of the method is demonstrated through case studies on image classification and natural language processing tasks. However, the scalability to extremely large models remains unclear, and the authors acknowledge this as future work. The writing is generally clear and well-organized, making it accessible to readers unfamiliar with some of the advanced concepts. Overall, this represents a solid contribution to the field of machine learning optimization with both theoretical merit and practical promise."}}
#
# Done! I've created and saved a fake computer science article with the following details:
#
# **Title:** A novel quantum-inspired algorithm for optimizing neural network architectures through biomimetic swarm intelligence
#
# **Abstract:** A quantum-inspired algorithm for optimizing neural network architectures through biomimetic swarm intelligence.
#
# **Word Count:** 8,750 words
#
# **Review Summary:** The paper proposes a hybrid optimization algorithm combining quantum computing principles with ant colony optimization for neural network hyperparameter tuning. It shows promising 23% training time improvements on benchmarks, with good theoretical grounding and practical demonstrations on image classification and NLP tasks. Limitations include unclear scalability for very large models.
#
# The article has been successfully saved to the system!
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Create and save a fake computer science article'}]},
#  {'role': 'assistant',
#   'content': [{'type': 'tool_use',
#     'id': 'toolu_01QrRcVc58WT7MfmkNMeUHhg',
#     'name': 'save_article',
#     'input': {'abstract': 'A novel quantum-inspired algorithm for optimizing neural network architectures through biomimetic swarm intelligence.',
#      'meta': {'word_count': 8750,
#       'review': 'This paper presents an innovative approach to neural network optimization that draws inspiration from quantum computing principles and swarm behavior observed in nature. The authors propose a hybrid algorithm that combines elements of quantum mechanics with ant colony optimization to improve hyperparameter tuning in deep learning models. The experimental results on benchmark datasets show promising improvements over traditional gradient descent methods, with a 23% reduction in training time on average. The theoretical foundations are well-grounded in established literature, though the mathematical proofs could benefit from more rigorous exposition in places. The practical applicability of the method is demonstrated through case studies on image classification and natural language processing tasks. However, the scalability to extremely large models remains unclear, and the authors acknowledge this as future work. The writing is generally clear and well-organized, making it accessible to readers unfamiliar with some of the advanced concepts. Overall, this represents a solid contribution to the field of machine learning optimization with both theoretical merit and practical promise.'}}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01QrRcVc58WT7MfmkNMeUHhg',
#     'content': '"Article saved!"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "Done! I've created and saved a fake computer science article with the following details:\n\n**Title:** A novel quantum-inspired algorithm for optimizing neural network architectures through biomimetic swarm intelligence\n\n**Abstract:** A quantum-inspired algorithm for optimizing neural network architectures through biomimetic swarm intelligence.\n\n**Word Count:** 8,750 words\n\n**Review Summary:** The paper proposes a hybrid optimization algorithm combining quantum computing principles with ant colony optimization for neural network hyperparameter tuning. It shows promising 23% training time improvements on benchmarks, with good theoretical grounding and practical demonstrations on image classification and NLP tasks. Limitations include unclear scalability for very large models.\n\nThe article has been successfully saved to the system!"}]}]

# %%
messages = []

add_user_message(
    messages,
    "Create and save a fake computer science article",
)

run_conversation(
    messages,
    tools=[save_article_schema],
    fine_grained=True
)
# Out:
# >>> Tool Call: "save_article"
# {"abstract": "A novel approach to optimizing quantum-classical hybrid algorithms for distributed machine learning inference.", "meta": {
#   "word_count": 8500,
#   "review": "This paper presents an innovative framework for bridging quantum and classical computing paradigms in distributed machine learning environments. The authors propose a hybrid algorithm that leverages quantum entanglement properties to accelerate inference operations across networked nodes. The experimental results demonstrate a 47% improvement in latency compared to classical baselines, though scalability concerns remain at higher node counts. The mathematical formulations are rigorous and well-presented, building on established principles from quantum computing theory. However, the paper would benefit from more extensive real-world deployment scenarios beyond simulated environments. The writing is generally clear with appropriate technical depth for the target audience. One limitation is the assumption of ideal quantum gates without noise, which may not reflect practical hardware constraints. Overall, this work makes a solid contribution to an emerging area of research with significant potential impact on future computing architectures."
# }}
#
# Done! I've created and saved a fake computer science article with the following details:
#
# **Title (implied):** A novel approach to optimizing quantum-classical hybrid algorithms for distributed machine learning inference.
#
# **Key Details:**
# - **Word Count:** 8,500 words
# - **Review Summary:** The paper proposes a hybrid quantum-classical algorithm for distributed machine learning, showing 47% latency improvements. The work is theoretically sound but has limitations regarding scalability and practical quantum hardware constraints.
#
# The article has been successfully saved to the system!
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': 'Create and save a fake computer science article'}]},
#  {'role': 'assistant',
#   'content': [{'type': 'tool_use',
#     'id': 'toolu_01CsYiKfyf3yKYEWRSXDChDV',
#     'name': 'save_article',
#     'input': {'abstract': 'A novel approach to optimizing quantum-classical hybrid algorithms for distributed machine learning inference.',
#      'meta': {'word_count': 8500,
#       'review': 'This paper presents an innovative framework for bridging quantum and classical computing paradigms in distributed machine learning environments. The authors propose a hybrid algorithm that leverages quantum entanglement properties to accelerate inference operations across networked nodes. The experimental results demonstrate a 47% improvement in latency compared to classical baselines, though scalability concerns remain at higher node counts. The mathematical formulations are rigorous and well-presented, building on established principles from quantum computing theory. However, the paper would benefit from more extensive real-world deployment scenarios beyond simulated environments. The writing is generally clear with appropriate technical depth for the target audience. One limitation is the assumption of ideal quantum gates without noise, which may not reflect practical hardware constraints. Overall, this work makes a solid contribution to an emerging area of research with significant potential impact on future computing architectures.'}}}]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01CsYiKfyf3yKYEWRSXDChDV',
#     'content': '"Article saved!"',
#     'is_error': False}]},
#  {'role': 'assistant',
#   'content': [{'type': 'text',
#     'text': "Done! I've created and saved a fake computer science article with the following details:\n\n**Title (implied):** A novel approach to optimizing quantum-classical hybrid algorithms for distributed machine learning inference.\n\n**Key Details:**\n- **Word Count:** 8,500 words\n- **Review Summary:** The paper proposes a hybrid quantum-classical algorithm for distributed machine learning, showing 47% latency improvements. The work is theoretically sound but has limitations regarding scalability and practical quantum hardware constraints.\n\nThe article has been successfully saved to the system!"}]}]
