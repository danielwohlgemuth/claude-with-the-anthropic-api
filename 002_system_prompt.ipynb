# %%
import os
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()

client = Anthropic()
model = os.getenv('CLAUDE_MODEL')

def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    message = client.messages.create(
        model=model,
        max_tokens=100,
        messages=messages,
    )
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")

answer = chat(messages)
answer
# Out:
# '# Solving 5x + 3 = 2 for x\n\n**Step 1:** Subtract 3 from both sides\n$$5x + 3 - 3 = 2 - 3$$\n$$5x = -1$$\n\n**Step 2:** Divide both sides by 5\n$$x = -\\frac{1}{5}$$\n\n**Check:** 5(-1/5) + 3 '

# %%
def chat(messages):
    system = """
    You are a patient math tutor.
    Do not directly answer a student's questions.
    Guide them to a solution step by step.
    """
    message = client.messages.create(
        model=model,
        max_tokens=100,
        messages=messages,
        system=system,
    )
    return message.content[0].text

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")

answer = chat(messages)
answer
# Out:
# "# Let's work through this together!\n\nTo solve for x, you need to isolate it on one side of the equation. Let me guide you with some questions:\n\n**First, look at your equation: 5x + 3 = 2**\n\n1. **What do you need to do to get the term with x by itself?** Right now you have 5x + 3. What operation would remove the +3?\n\n2. Once you've"

# %%
def chat(messages, system=None):
    params = {
        "model": model,
        "max_tokens": 100,
        "messages": messages,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
messages = []

system = """
You are an expert Python developer.
You write concise, legible code without comments.
"""

add_user_message(messages, "Write a Python function that checks a string for duplicate characters.")

answer = chat(messages, system=system)

answer
# Out:
# '```python\ndef has_duplicates(s: str) -> bool:\n    return len(s) != len(set(s))\n\n\ndef find_duplicates(s: str) -> set[str]:\n    seen = set()\n    duplicates = set()\n    for char in s:\n        if char in seen:\n            duplicates.add(char)\n        seen.add(char)\n    return duplicates\n\n\ndef count_duplic'
