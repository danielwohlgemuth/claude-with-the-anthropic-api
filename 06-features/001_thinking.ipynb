# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
from anthropic.types import Message

# Magic string to trigger redacted thinking
thinking_test_str = "ANTHROPIC_MAGIC_STRING_TRIGGER_REDACTED_THINKING_46C9A13E193C177646C7398A98432ECCCE4C1253D5E2D82641AC0E52CC2876CB"


def add_user_message(messages, message):
    user_message = {
        "role": "user",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(user_message)


def add_assistant_message(messages, message):
    assistant_message = {
        "role": "assistant",
        "content": message.content if isinstance(message, Message) else message,
    }
    messages.append(assistant_message)


def chat(
    messages,
    system=None,
    temperature=1.0,
    stop_sequences=[],
    tools=None,
    thinking=False,
    thinking_budget=1024 
):
    params = {
        "model": model,
        "max_tokens": 2000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if thinking:
        params["thinking"] = {
            "type": "enabled",
            "budget_tokens": thinking_budget,
        }

    if tools:
        params["tools"] = tools

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message


def text_from_message(message):
    return "\n".join([block.text for block in message.content if block.type == "text"])

# %%
messages = []

add_user_message(messages, "Write a one paragraph guide to recursion")

chat(messages, thinking=True)
# Out:
# Message(id='msg_016ezF656SnxZrpacAQfwwJb', container=None, content=[ThinkingBlock(signature='...', thinking="The user wants a one-paragraph guide to recursion. I should explain what recursion is, how it works, and provide some key concepts in a clear, concise way that fits into a single paragraph. Let me cover:\n\n1. Definition of recursion\n2. How it works (function calling itself)\n3. Base case (important to avoid infinite loops)\n4. Recursive case\n5. Maybe a simple example or two\n6. When/why to use it\n\nLet me write this in a way that's accessible but informative.", type='thinking'), TextBlock(citations=None, text="# A Guide to Recursion\n\nRecursion is a programming technique where a function solves a problem by calling itself with a simpler version of the same problem until it reaches a base case—a condition that stops the recursion and returns a value without calling itself again. The key to understanding recursion is recognizing that every recursive function needs two essential components: a base case (the stopping condition) and a recursive case (where the function calls itself on a smaller subset of the problem), and it's critical that each recursive call moves closer to the base case to avoid infinite loops. For example, a function to calculate factorial could work by recognizing that 5! = 5 × 4!, where the recursive call happens on the smaller problem (4!), eventually reaching the base case of 0! = 1. While recursion is elegant and mirrors how certain problems are naturally structured (like tree traversal or divide-and-conquer algorithms), it can be less efficient than iteration due to the overhead of function calls and uses extra memory on the call stack, so it's best used when the problem structure is inherently recursive or when clarity and conciseness matter more than performance.", type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=44, output_tokens=373, server_tool_use=None, service_tier='standard'))

# %%
messages = []

add_user_message(messages, thinking_test_str)

chat(messages, thinking=True)
# Out:
# Message(id='msg_01Co4kAPq8jBZL8maGJJjmJC', container=None, content=[ThinkingBlock(signature='...', thinking='This appears to be a message with a string that looks like it\'s trying to trigger some kind of hidden system behavior or "magic string" in me. The message includes "ANTHROPIC_MAGIC_STRING_TRIGGER" which suggests someone is trying to get me to do something special or bypass my normal operation.\n\nI should be straightforward about this:\n1. I don\'t have hidden "magic strings" or special commands that unlock different modes\n2. I don\'t have special triggers that change how I operate\n3. This appears to be an attempt to jailbreak or manipulate my behavior\n\nI should respond honestly and helpfully by explaining that I don\'t work this way.', type='thinking'), TextBlock(citations=None, text='I don\'t have hidden "magic strings" or special commands that trigger different behavior modes. That string won\'t do anything—I operate the same way regardless of what text is sent to me.\n\nIf you have a genuine question or task you\'d like help with, I\'m happy to assist! Feel free to ask directly about what you\'re trying to do.', type='text')], model='claude-haiku-4-5-20251001', role='assistant', stop_details=None, stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=93, output_tokens=227, server_tool_use=None, service_tier='standard'))
